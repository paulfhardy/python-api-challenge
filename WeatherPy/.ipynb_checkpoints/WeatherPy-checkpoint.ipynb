# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from datetime import date


from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

today = date.today()
today
# Out:
# datetime.date(2020, 7, 28)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)


# Print the city count to confirm sufficient count

len(cities)
# Out:
# 631

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"

# Build partial query URL

city = 'Avarua'
units = 'Imperial'
query_url = f"{url}appid={weather_api_key}&units={units}&q="
# print(query_url)

response = requests.get(query_url + city).json()
# print(response)

print(json.dumps(response, indent=4))
# Out:
# {
#     "coord": {
#         "lon": -159.78,
#         "lat": -21.21
#     },
#     "weather": [
#         {
#             "id": 803,
#             "main": "Clouds",
#             "description": "broken clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 71.6,
#         "feels_like": 74.91,
#         "temp_min": 71.6,
#         "temp_max": 71.6,
#         "pressure": 1011,
#         "humidity": 88
#     },
#     "visibility": 7000,
#     "wind": {
#         "speed": 5.82,
#         "deg": 130
#     },
#     "clouds": {
#         "all": 73
#     },
#     "dt": 1595986554,
#     "sys": {
#         "type": 1,
#         "id": 7271,
#         "country": "CK",
#         "sunrise": 1595956321,
#         "sunset": 1595996338
#     },
#     "timezone": -36000,
#     "id": 4035715,
#     "name": "Avarua",
#     "cod": 200
# }

# %%
# Setup a loop to loop through each city in cities and get the relevant weather info + lat and longtitude info
# since all lats and lngs didn't retrieve a city (lists are of a different length) so we must handle that via a 
# try/except condition.
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
city_name = []
city_lats = []
city_lngs = []
city_datetime = []
city_country = []


counter = 0
for city in cities:
    counter = counter + 1
    if counter == 1000:
        break
    response = requests.get(query_url + city).json()
    #print(query_url)
    try:
        max_temp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        city_name.append(response['name'])
        city_datetime.append(response['dt'])
        city_country.append(response['sys']['country'])
        city_lats.append(response['coord']['lat'])
        city_lngs.append(response['coord']['lon'])
        print(f"Retrieving weather data for {city}, city ID:{response['id']}")
    except:    
        print(f"DATA FOR {city} NOT FOUND IN THE WEATHER API")
        pass
# Out:
# DATA FOR illoqqortoormiut NOT FOUND IN THE WEATHER API
# Retrieving weather data for kapaa, city ID:5848280
# Retrieving weather data for pisco, city ID:3932145
# Retrieving weather data for narsaq, city ID:3421719
# Retrieving weather data for samana, city ID:3492997
# DATA FOR taolanaro NOT FOUND IN THE WEATHER API
# Retrieving weather data for sulangan, city ID:1685422
# Retrieving weather data for punta arenas, city ID:3874787
# Retrieving weather data for camacari, city ID:3468031
# Retrieving weather data for rikitea, city ID:4030556
# Retrieving weather data for mogok, city ID:1308937
# Retrieving weather data for atuona, city ID:4020109
# Retrieving weather data for clinton, city ID:4989133
# Retrieving weather data for arraial do cabo, city ID:3471451
# Retrieving weather data for pokaran, city ID:1259460
# Retrieving weather data for mahebourg, city ID:934322
# Retrieving weather data for dongsheng, city ID:1812256
# Retrieving weather data for galesong, city ID:1644605
# Retrieving weather data for hithadhoo, city ID:1282256
# Retrieving weather data for cape town, city ID:3369157
# Retrieving weather data for barrow, city ID:5880054
# Retrieving weather data for kenai, city ID:5866063
# Retrieving weather data for quatre cocos, city ID:1106643
# Retrieving weather data for butaritari, city ID:2110227
# Retrieving weather data for ushuaia, city ID:3833367
# Retrieving weather data for isangel, city ID:2136825
# Retrieving weather data for sorland, city ID:3137469
# Retrieving weather data for valparaiso, city ID:3868626
# Retrieving weather data for mehamn, city ID:778707
# Retrieving weather data for mar del plata, city ID:3430863
# Retrieving weather data for namibe, city ID:3347019
# Retrieving weather data for leningradskiy, city ID:2123814
# Retrieving weather data for saskylakh, city ID:2017155
# Retrieving weather data for oranjemund, city ID:3354071
# Retrieving weather data for vila franca do campo, city ID:3372472
# Retrieving weather data for avarua, city ID:4035715
# Retrieving weather data for aljezur, city ID:2271968
# DATA FOR phan rang NOT FOUND IN THE WEATHER API
# Retrieving weather data for te anau, city ID:2181625
# Retrieving weather data for severo-kurilsk, city ID:2121385
# Retrieving weather data for ossora, city ID:2122389
# Retrieving weather data for virginia beach, city ID:4791259
# Retrieving weather data for biak, city ID:1637001
# Retrieving weather data for kieta, city ID:2094027
# Retrieving weather data for ponta do sol, city ID:2264557
# Retrieving weather data for hilo, city ID:5855927
# Retrieving weather data for vostok, city ID:2013279
# Retrieving weather data for vodnyy, city ID:472976
# DATA FOR belushya guba NOT FOUND IN THE WEATHER API
# Retrieving weather data for lisakovsk, city ID:1521315
# Retrieving weather data for atar, city ID:2381334
# Retrieving weather data for gamba, city ID:2400547
# Retrieving weather data for tsogni, city ID:2400547
# Retrieving weather data for kununurra, city ID:2068110
# Retrieving weather data for faya, city ID:110690
# Retrieving weather data for lashio, city ID:1314759
# Retrieving weather data for ust-kut, city ID:2013923
# Retrieving weather data for cidreira, city ID:3466165
# DATA FOR nizhneyansk NOT FOUND IN THE WEATHER API
# Retrieving weather data for port keats, city ID:2063039
# Retrieving weather data for mama, city ID:2020313
# Retrieving weather data for mataura, city ID:6201424
# Retrieving weather data for wanaka, city ID:2184707
# Retrieving weather data for eyl, city ID:60019
# Retrieving weather data for hobyo, city ID:57000
# Retrieving weather data for boyolangu, city ID:1648082
# Retrieving weather data for thompson, city ID:6165406
# Retrieving weather data for hermanus, city ID:3366880
# DATA FOR mys shmidta NOT FOUND IN THE WEATHER API
# Retrieving weather data for saint george, city ID:5546220
# Retrieving weather data for tasiilaq, city ID:3424607
# Retrieving weather data for clonakilty, city ID:2965402
# Retrieving weather data for comodoro rivadavia, city ID:3860443
# Retrieving weather data for den helder, city ID:2757220
# Retrieving weather data for kurilsk, city ID:2123979
# Retrieving weather data for jamestown, city ID:5122534
# Retrieving weather data for vaini, city ID:4032243
# Retrieving weather data for dimitrovgrad, city ID:566199
# Retrieving weather data for georgetown, city ID:1735106
# Retrieving weather data for shizunai, city ID:2128025
# Retrieving weather data for nchelenge, city ID:175499
# DATA FOR vaitupu NOT FOUND IN THE WEATHER API
# Retrieving weather data for nanortalik, city ID:3421765
# Retrieving weather data for rio grande, city ID:3451138
# Retrieving weather data for shenjiamen, city ID:1795632
# Retrieving weather data for san patricio, city ID:3985168
# Retrieving weather data for busselton, city ID:2075265
# Retrieving weather data for tiksi, city ID:2015306
# Retrieving weather data for ampanihy, city ID:1078553
# Retrieving weather data for yellowknife, city ID:6185377
# Retrieving weather data for castro, city ID:3466704
# Retrieving weather data for tuktoyaktuk, city ID:6170031
# Retrieving weather data for puerto ayora, city ID:3652764
# Retrieving weather data for dunedin, city ID:2191562
# Retrieving weather data for lebu, city ID:3883457
# Retrieving weather data for goderich, city ID:5962442
# Retrieving weather data for gasa, city ID:281133
# Retrieving weather data for padang, city ID:1633419
# Retrieving weather data for pangody, city ID:1495626
# Retrieving weather data for mount isa, city ID:2065594
# DATA FOR tuggurt NOT FOUND IN THE WEATHER API
# Retrieving weather data for ancud, city ID:3899695
# Retrieving weather data for bluff, city ID:2206939
# Retrieving weather data for suhl, city ID:2824948
# Retrieving weather data for labuhan, city ID:8079926
# Retrieving weather data for havre-saint-pierre, city ID:5972291
# Retrieving weather data for panama city, city ID:3703443
# Retrieving weather data for kodiak, city ID:5866583
# Retrieving weather data for nara, city ID:1855612
# Retrieving weather data for alto araguaia, city ID:3472473
# Retrieving weather data for ventspils, city ID:454310
# Retrieving weather data for albany, city ID:5106841
# Retrieving weather data for souillac, city ID:933995
# Retrieving weather data for khatanga, city ID:2022572
# Retrieving weather data for hami, city ID:1529484
# Retrieving weather data for riyadh, city ID:108410
# DATA FOR tabarqah NOT FOUND IN THE WEATHER API
# Retrieving weather data for hobart, city ID:2163355
# Retrieving weather data for olafsvik, city ID:3414079
# Retrieving weather data for anahuac, city ID:4013726
# Retrieving weather data for buala, city ID:2109528
# Retrieving weather data for smirnykh, city ID:2121126
# Retrieving weather data for cherskiy, city ID:2126199
# Retrieving weather data for luderitz, city ID:3355672
# DATA FOR barentsburg NOT FOUND IN THE WEATHER API
# Retrieving weather data for chitral, city ID:1181065
# Retrieving weather data for kaitangata, city ID:2208248
# Retrieving weather data for guerrero negro, city ID:4021858
# Retrieving weather data for strezhevoy, city ID:1490796
# Retrieving weather data for sur, city ID:286245
# Retrieving weather data for khandbari, city ID:1283217
# Retrieving weather data for saint-georges, city ID:3579925
# Retrieving weather data for amapa, city ID:3407762
# Retrieving weather data for klaksvik, city ID:2618795
# Retrieving weather data for rocha, city ID:3440777
# Retrieving weather data for benguela, city ID:3351663
# Retrieving weather data for zelenoborsk, city ID:1485286
# Retrieving weather data for inhambane, city ID:1045114
# Retrieving weather data for adrar, city ID:2381972
# Retrieving weather data for srednekolymsk, city ID:2121025
# Retrieving weather data for taltal, city ID:3870243
# Retrieving weather data for cerknica, city ID:3202709
# Retrieving weather data for dehui, city ID:2037712
# Retrieving weather data for sangar, city ID:2017215
# Retrieving weather data for valerianovsk, city ID:477280
# Retrieving weather data for tabas, city ID:113659
# DATA FOR temaraia NOT FOUND IN THE WEATHER API
# Retrieving weather data for lompoc, city ID:5367788
# Retrieving weather data for bredasdorp, city ID:1015776
# Retrieving weather data for alanya, city ID:324190
# Retrieving weather data for the valley, city ID:3573374
# Retrieving weather data for huarmey, city ID:3939168
# Retrieving weather data for kachug, city ID:2023333
# Retrieving weather data for alexandria, city ID:361058
# Retrieving weather data for bengkulu, city ID:1649150
# Retrieving weather data for priyutnoye, city ID:505019
# Retrieving weather data for namatanai, city ID:2090021
# Retrieving weather data for dudinka, city ID:1507116
# Retrieving weather data for leninskoye, city ID:2020841
# Retrieving weather data for bedi, city ID:1276627
# Retrieving weather data for lang suan, city ID:1152432
# Retrieving weather data for rosarito, city ID:3988392
# Retrieving weather data for touros, city ID:3386213
# Retrieving weather data for cozumel, city ID:3530103
# Retrieving weather data for upernavik, city ID:3418910
# Retrieving weather data for cayenne, city ID:3382160
# Retrieving weather data for tessalit, city ID:2449893
# Retrieving weather data for cabo san lucas, city ID:3985710
# Retrieving weather data for tokonou, city ID:2414659
# Retrieving weather data for axim, city ID:2303611
# Retrieving weather data for airai, city ID:1651810
# DATA FOR bolungarvik NOT FOUND IN THE WEATHER API
# Retrieving weather data for kloulklubed, city ID:7671223
# Retrieving weather data for bilma, city ID:2446796
# Retrieving weather data for karasjok, city ID:779350
# Retrieving weather data for port alfred, city ID:964432
# Retrieving weather data for arlit, city ID:2447513
# Retrieving weather data for vinh, city ID:1562798
# Retrieving weather data for vardo, city ID:777019
# Retrieving weather data for lata, city ID:2738381
# Retrieving weather data for sao gabriel da cachoeira, city ID:3662342
# Retrieving weather data for champasak, city ID:1657818
# Retrieving weather data for iqaluit, city ID:5983720
# Retrieving weather data for santa lucia, city ID:2511150
# Retrieving weather data for east london, city ID:1006984
# Retrieving weather data for grand-santi, city ID:3381538
# DATA FOR sentyabrskiy NOT FOUND IN THE WEATHER API
# Retrieving weather data for beipiao, city ID:2038342
# Retrieving weather data for hambantota, city ID:1244926
# DATA FOR samusu NOT FOUND IN THE WEATHER API
# Retrieving weather data for nikolskoye, city ID:546105
# Retrieving weather data for pevek, city ID:2122090
# Retrieving weather data for rio gallegos, city ID:3838859
# Retrieving weather data for faanui, city ID:4034551
# Retrieving weather data for ribeira grande, city ID:3372707
# Retrieving weather data for waddan, city ID:2209055
# Retrieving weather data for tuatapere, city ID:2180815
# Retrieving weather data for dikson, city ID:1507390
# Retrieving weather data for naryan-mar, city ID:523392
# DATA FOR tsihombe NOT FOUND IN THE WEATHER API
# Retrieving weather data for flinders, city ID:6255012
# Retrieving weather data for zyryanka, city ID:2119283
# Retrieving weather data for saint-philippe, city ID:935215
# Retrieving weather data for kavieng, city ID:2094342
# DATA FOR aflu NOT FOUND IN THE WEATHER API
# DATA FOR saleaula NOT FOUND IN THE WEATHER API
# Retrieving weather data for tacoronte, city ID:2510725
# Retrieving weather data for katsuura, city ID:2112309
# Retrieving weather data for glencoe, city ID:1001736
# Retrieving weather data for beaverlodge, city ID:5896969
# Retrieving weather data for ushtobe, city ID:1517637
# Retrieving weather data for atambua, city ID:1651103
# Retrieving weather data for kahului, city ID:5847411
# Retrieving weather data for chuy, city ID:3443061
# Retrieving weather data for mariinsk, city ID:1499350
# Retrieving weather data for tezu, city ID:1254709
# Retrieving weather data for iskateley, city ID:866062
# Retrieving weather data for muros, city ID:3115824
# Retrieving weather data for dasoguz, city ID:601734
# Retrieving weather data for stanos, city ID:253286
# Retrieving weather data for new norfolk, city ID:2155415
# Retrieving weather data for mount gambier, city ID:2156643
# Retrieving weather data for boundiali, city ID:2290836
# Retrieving weather data for coahuayana, city ID:4013679
# Retrieving weather data for point pedro, city ID:1229989
# Retrieving weather data for smithers, city ID:6149996
# Retrieving weather data for ust-nera, city ID:2120048
# DATA FOR aporawan NOT FOUND IN THE WEATHER API
# Retrieving weather data for longyearbyen, city ID:2729907
# Retrieving weather data for half moon bay, city ID:5354943
# Retrieving weather data for panaba, city ID:3521972
# Retrieving weather data for college, city ID:5859699
# Retrieving weather data for samfya, city ID:899274
# Retrieving weather data for waingapu, city ID:1622318
# Retrieving weather data for santa flavia, city ID:2523352
# Retrieving weather data for alekseyevsk, city ID:2022083
# DATA FOR dzhusaly NOT FOUND IN THE WEATHER API
# Retrieving weather data for sweetwater, city ID:4174600
# Retrieving weather data for ambon, city ID:1651531
# Retrieving weather data for awbari, city ID:2219235
# Retrieving weather data for bambous virieux, city ID:1106677
# Retrieving weather data for gemena, city ID:2315728
# Retrieving weather data for phalaborwa, city ID:965528
# Retrieving weather data for kawalu, city ID:1640902
# Retrieving weather data for cockburn town, city ID:3576994
# Retrieving weather data for hovd, city ID:1516048
# Retrieving weather data for hamilton, city ID:4513583
# Retrieving weather data for ostrovnoy, city ID:556268
# Retrieving weather data for kohat, city ID:1173491
# Retrieving weather data for yinchuan, city ID:1786657
# Retrieving weather data for bayburt, city ID:750938
# Retrieving weather data for songkhla, city ID:1606146
# DATA FOR karaul NOT FOUND IN THE WEATHER API
# Retrieving weather data for itarema, city ID:3393692
# Retrieving weather data for kisangani, city ID:212730
# Retrieving weather data for zhob, city ID:1162105
# Retrieving weather data for praya, city ID:3374333
# Retrieving weather data for mugur-aksy, city ID:1498283
# Retrieving weather data for port lincoln, city ID:2063036
# Retrieving weather data for kodinsk, city ID:1503037
# Retrieving weather data for kalmunai, city ID:1242110
# Retrieving weather data for rawson, city ID:3839307
# Retrieving weather data for kemijarvi, city ID:653272
# Retrieving weather data for san quintin, city ID:3984997
# Retrieving weather data for dombarovskiy, city ID:565407
# Retrieving weather data for husavik, city ID:2629833
# Retrieving weather data for parabel, city ID:1495586
# Retrieving weather data for anadyr, city ID:2127202
# Retrieving weather data for clyde river, city ID:5924351
# Retrieving weather data for jacareacanga, city ID:3397763
# Retrieving weather data for iquitos, city ID:3696183
# Retrieving weather data for codrington, city ID:2171099
# Retrieving weather data for qaqortoq, city ID:3420846
# Retrieving weather data for marau, city ID:3457817
# Retrieving weather data for jacksonville, city ID:4160021
# Retrieving weather data for kavaratti, city ID:1267390
# Retrieving weather data for la ronge, city ID:6050066
# Retrieving weather data for beyneu, city ID:610298
# Retrieving weather data for beidao, city ID:1816751
# Retrieving weather data for nguruka, city ID:151567
# Retrieving weather data for fortuna, city ID:5563839
# Retrieving weather data for mogadishu, city ID:53654
# Retrieving weather data for sesheke, city ID:898905
# Retrieving weather data for kiama, city ID:2161515
# DATA FOR grand river south east NOT FOUND IN THE WEATHER API
# Retrieving weather data for cadereyta, city ID:3531865
# Retrieving weather data for takoradi, city ID:2294915
# Retrieving weather data for cassilandia, city ID:3466750
# Retrieving weather data for najran, city ID:103630
# DATA FOR amderma NOT FOUND IN THE WEATHER API
# Retrieving weather data for ugoofaaru, city ID:1337619
# Retrieving weather data for ust-omchug, city ID:2120047
# Retrieving weather data for shubarkuduk, city ID:608271
# Retrieving weather data for bintulu, city ID:1737486
# Retrieving weather data for vila velha, city ID:3445026
# Retrieving weather data for buin, city ID:3897774
# Retrieving weather data for porbandar, city ID:1259395
# Retrieving weather data for socuellamos, city ID:2510852
# Retrieving weather data for saint-francois, city ID:2980080
# Retrieving weather data for fukue, city ID:1863997
# Retrieving weather data for lardos, city ID:408689
# Retrieving weather data for mandalgovi, city ID:2030065
# Retrieving weather data for gazanjyk, city ID:161974
# Retrieving weather data for lagoa, city ID:3372964
# Retrieving weather data for dhidhdhoo, city ID:1337612
# Retrieving weather data for fort frances, city ID:5955826
# Retrieving weather data for barkhan, city ID:1183307
# Retrieving weather data for bowen, city ID:2174444
# Retrieving weather data for lorengau, city ID:2092164
# Retrieving weather data for guadalajara, city ID:4005539
# Retrieving weather data for tukrah, city ID:88834
# DATA FOR viligili NOT FOUND IN THE WEATHER API
# Retrieving weather data for ambilobe, city ID:1082243
# Retrieving weather data for butembo, city ID:217562
# Retrieving weather data for semey, city ID:1519422
# Retrieving weather data for gorgan, city ID:132892
# Retrieving weather data for taoudenni, city ID:2450173
# Retrieving weather data for portland, city ID:5746545
# Retrieving weather data for camana, city ID:3945985
# Retrieving weather data for harboore, city ID:2620767
# Retrieving weather data for geraldton, city ID:2070998
# Retrieving weather data for mirnyy, city ID:2019951
# Retrieving weather data for dwarka, city ID:1272140
# Retrieving weather data for port hedland, city ID:2063042
# Retrieving weather data for batabano, city ID:3567655
# Retrieving weather data for chokurdakh, city ID:2126123
# Retrieving weather data for marsh harbour, city ID:3571913
# Retrieving weather data for bhopalwala, city ID:1182577
# Retrieving weather data for broken hill, city ID:2173911
# Retrieving weather data for porto velho, city ID:3662762
# Retrieving weather data for meulaboh, city ID:1214488
# Retrieving weather data for mingyue, city ID:2035754
# Retrieving weather data for at-bashi, city ID:1528796
# Retrieving weather data for bantry, city ID:2966356
# DATA FOR khonuu NOT FOUND IN THE WEATHER API
# Retrieving weather data for batemans bay, city ID:2176639
# Retrieving weather data for verkh-chebula, city ID:1487599
# Retrieving weather data for bethel, city ID:5282297
# DATA FOR yialos NOT FOUND IN THE WEATHER API
# Retrieving weather data for hay river, city ID:5972762
# Retrieving weather data for teya, city ID:1489656
# Retrieving weather data for okhotsk, city ID:2122605
# Retrieving weather data for nemuro, city ID:2128975
# Retrieving weather data for cap-aux-meules, city ID:5915327
# Retrieving weather data for xining, city ID:1788852
# Retrieving weather data for salamiyah, city ID:164947
# Retrieving weather data for chapais, city ID:5919850
# Retrieving weather data for provideniya, city ID:4031574
# Retrieving weather data for shelbyville, city ID:4657077
# DATA FOR taburi NOT FOUND IN THE WEATHER API
# Retrieving weather data for rameshki, city ID:502903
# Retrieving weather data for cape canaveral, city ID:4149959
# Retrieving weather data for sosva, city ID:1491267
# Retrieving weather data for pervomayskiy, city ID:510911
# Retrieving weather data for sangmelima, city ID:2222230
# Retrieving weather data for karatau, city ID:1519938
# DATA FOR bengkalis NOT FOUND IN THE WEATHER API
# Retrieving weather data for mitsamiouli, city ID:921786
# Retrieving weather data for bibiani, city ID:2303060
# Retrieving weather data for dehloran, city ID:136702
# DATA FOR navapur NOT FOUND IN THE WEATHER API
# DATA FOR tumannyy NOT FOUND IN THE WEATHER API
# DATA FOR sulurpeta NOT FOUND IN THE WEATHER API
# Retrieving weather data for bella union, city ID:3443631
# Retrieving weather data for tabou, city ID:2281120
# Retrieving weather data for mabamba, city ID:155514
# Retrieving weather data for hasaki, city ID:2112802
# Retrieving weather data for pangoa, city ID:3933104
# Retrieving weather data for buchanan, city ID:2278158
# Retrieving weather data for tabuk, city ID:1684803
# Retrieving weather data for zhengjiatun, city ID:2033135
# Retrieving weather data for tres arroyos, city ID:3833859
# Retrieving weather data for pangnirtung, city ID:6096551
# Retrieving weather data for viedma, city ID:3832899
# Retrieving weather data for nanga eboko, city ID:2225457
# Retrieving weather data for yerbogachen, city ID:2012956
# Retrieving weather data for port augusta, city ID:2063056
# Retrieving weather data for berlevag, city ID:780687
# Retrieving weather data for lang son, city ID:1576633
# Retrieving weather data for acapulco, city ID:3533462
# Retrieving weather data for nalundan, city ID:1698446
# Retrieving weather data for aksu, city ID:1529660
# Retrieving weather data for balezino, city ID:579432
# Retrieving weather data for riverton, city ID:5780557
# Retrieving weather data for mbandaka, city ID:2312895
# Retrieving weather data for sao felix do xingu, city ID:3388847
# Retrieving weather data for puerto escondido, city ID:3520994
# Retrieving weather data for grand-lahou, city ID:2288105
# Retrieving weather data for kiruna, city ID:605155
# Retrieving weather data for vila do maio, city ID:3374120
# Retrieving weather data for margate, city ID:2643044
# Retrieving weather data for puerto leguizamo, city ID:3671437
# Retrieving weather data for aswan, city ID:359792
# Retrieving weather data for egvekinot, city ID:4031742
# DATA FOR bokspits NOT FOUND IN THE WEATHER API
# Retrieving weather data for ajaigarh, city ID:1279181
# Retrieving weather data for glendive, city ID:5654391
# Retrieving weather data for melilla, city ID:2513947
# Retrieving weather data for novorozhdestvenskaya, city ID:518249
# DATA FOR chagda NOT FOUND IN THE WEATHER API
# Retrieving weather data for baykit, city ID:1510689
# Retrieving weather data for troitsko-pechorsk, city ID:481548
# Retrieving weather data for livingston, city ID:2644204
# Retrieving weather data for ginda, city ID:1253628
# Retrieving weather data for salalah, city ID:286621
# Retrieving weather data for turukhansk, city ID:1488903
# Retrieving weather data for guiratinga, city ID:3461733
# Retrieving weather data for port elizabeth, city ID:964420
# Retrieving weather data for alamosa, city ID:5411479
# DATA FOR jinchengjiang NOT FOUND IN THE WEATHER API
# Retrieving weather data for tayginka, city ID:1489900
# Retrieving weather data for komsomolskiy, city ID:1513491
# DATA FOR samalaeulu NOT FOUND IN THE WEATHER API
# Retrieving weather data for camacha, city ID:2270385
# Retrieving weather data for tsybli, city ID:691052
# DATA FOR vizimyary NOT FOUND IN THE WEATHER API
# Retrieving weather data for newtownards, city ID:2641519
# Retrieving weather data for moron, city ID:3430545
# Retrieving weather data for tocopilla, city ID:3869716
# Retrieving weather data for luena, city ID:3347719
# Retrieving weather data for skelleftea, city ID:602913
# Retrieving weather data for lavrentiya, city ID:4031637
# DATA FOR lushunkou NOT FOUND IN THE WEATHER API
# Retrieving weather data for tuensang, city ID:1254133
# Retrieving weather data for bereda, city ID:3105522
# Retrieving weather data for coquimbo, city ID:3893629
# Retrieving weather data for fort nelson, city ID:5955902
# Retrieving weather data for yen bai, city ID:1560349
# Retrieving weather data for leshukonskoye, city ID:535839
# Retrieving weather data for caracuaro, city ID:4015471
# Retrieving weather data for bambanglipuro, city ID:1650434
# Retrieving weather data for linjiang, city ID:2036069
# Retrieving weather data for avera, city ID:4231997
# Retrieving weather data for edd, city ID:338345
# Retrieving weather data for palakollu, city ID:1260792
# Retrieving weather data for krasnoselkup, city ID:1502073
# DATA FOR dianopolis NOT FOUND IN THE WEATHER API
# Retrieving weather data for brae, city ID:2654970
# Retrieving weather data for los llanos de aridane, city ID:2514651
# Retrieving weather data for omboue, city ID:2396853
# DATA FOR doctor pedro p. pena NOT FOUND IN THE WEATHER API
# Retrieving weather data for yeppoon, city ID:2142316
# Retrieving weather data for motygino, city ID:1498314
# Retrieving weather data for asarganj, city ID:1278308
# Retrieving weather data for grindavik, city ID:3416888
# Retrieving weather data for san policarpo, city ID:1688696
# Retrieving weather data for yar-sale, city ID:1486321
# Retrieving weather data for greece, city ID:5119251
# Retrieving weather data for coihaique, city ID:3894426
# Retrieving weather data for mungwi, city ID:904241
# Retrieving weather data for opuwo, city ID:3354077
# Retrieving weather data for quimper, city ID:2984701
# Retrieving weather data for maradi, city ID:2441291
# Retrieving weather data for naze, city ID:1855540
# Retrieving weather data for carnarvon, city ID:2074865
# Retrieving weather data for mustafakemalpasa, city ID:741385
# DATA FOR tabiauea NOT FOUND IN THE WEATHER API
# Retrieving weather data for kaniama, city ID:214389
# Retrieving weather data for manicore, city ID:3663503
# Retrieving weather data for quelimane, city ID:1028434
# Retrieving weather data for ramnagar, city ID:1258637
# Retrieving weather data for sakaiminato, city ID:1853174
# Retrieving weather data for cabedelo, city ID:3404558
# Retrieving weather data for nouakchott, city ID:2377450
# Retrieving weather data for port moresby, city ID:2088122
# Retrieving weather data for asfi, city ID:2537881
# Retrieving weather data for marlborough, city ID:2187304
# Retrieving weather data for zhangye, city ID:1785036
# Retrieving weather data for nelson bay, city ID:2155562
# Retrieving weather data for tual, city ID:1623197
# Retrieving weather data for san juan, city ID:3837213
# Retrieving weather data for norman wells, city ID:6089245
# Retrieving weather data for sao filipe, city ID:3374210
# Retrieving weather data for mayumba, city ID:2399001
# Retrieving weather data for spring hill, city ID:4173838
# DATA FOR lolua NOT FOUND IN THE WEATHER API
# Retrieving weather data for fairbanks, city ID:5861897
# Retrieving weather data for kyra, city ID:2021041
# Retrieving weather data for esperance, city ID:2071860
# Retrieving weather data for lamu, city ID:189741
# Retrieving weather data for sarkand, city ID:1519691
# Retrieving weather data for constitucion, city ID:3893726
# Retrieving weather data for sao lourenco do sul, city ID:3448596
# Retrieving weather data for pune, city ID:1259229
# Retrieving weather data for umm lajj, city ID:100926
# Retrieving weather data for auki, city ID:2109701
# Retrieving weather data for tubuala, city ID:3700393
# Retrieving weather data for karratha, city ID:6620339
# Retrieving weather data for cururupu, city ID:3401148
# Retrieving weather data for qaanaaq, city ID:3831208
# Retrieving weather data for feicheng, city ID:1811440
# Retrieving weather data for storsteinnes, city ID:3136023
# Retrieving weather data for kharan, city ID:1174062
# DATA FOR tingrela NOT FOUND IN THE WEATHER API
# Retrieving weather data for harindanga, city ID:1349090
# Retrieving weather data for roald, city ID:3141667
# Retrieving weather data for balyaga, city ID:2027173
# Retrieving weather data for beloha, city ID:1067565
# Retrieving weather data for lodwar, city ID:189280
# Retrieving weather data for lasa, city ID:3175096
# Retrieving weather data for leon, city ID:3998655
# Retrieving weather data for okha, city ID:2122614
# Retrieving weather data for khilok, city ID:2022463
# DATA FOR goteborg NOT FOUND IN THE WEATHER API
# Retrieving weather data for vangaindrano, city ID:1054329
# Retrieving weather data for salmas, city ID:117656
# Retrieving weather data for basco, city ID:1726449
# Retrieving weather data for trelew, city ID:3833883
# Retrieving weather data for campos altos, city ID:3467688
# Retrieving weather data for kayan, city ID:1319533
# Retrieving weather data for astara, city ID:148442
# Retrieving weather data for atasu, city ID:1526041
# DATA FOR attawapiskat NOT FOUND IN THE WEATHER API
# Retrieving weather data for delta del tigre, city ID:3442778
# Retrieving weather data for oktyabrskiy, city ID:515879
# Retrieving weather data for mountain home, city ID:5601615
# Retrieving weather data for deputatskiy, city ID:2028164
# Retrieving weather data for ban nahin, city ID:1661950
# Retrieving weather data for aklavik, city ID:5882953
# Retrieving weather data for sembe, city ID:2255304
# Retrieving weather data for trogir, city ID:3188763
# Retrieving weather data for firovo, city ID:562627
# Retrieving weather data for krasnokamensk, city ID:2021618
# Retrieving weather data for korla, city ID:1529376
# Retrieving weather data for torbay, city ID:6167817
# Retrieving weather data for dalmatovo, city ID:1507565
# Retrieving weather data for samarai, city ID:2132606
# Retrieving weather data for pontes e lacerda, city ID:3453060
# Retrieving weather data for toro, city ID:3666881
# Retrieving weather data for morgan city, city ID:4333811
# Retrieving weather data for orotukan, city ID:2122414
# Retrieving weather data for miracema do tocantins, city ID:3384937
# Retrieving weather data for lodja, city ID:211647
# Retrieving weather data for alta floresta, city ID:6316343
# DATA FOR dalinghe NOT FOUND IN THE WEATHER API
# Retrieving weather data for port-gentil, city ID:2396518
# DATA FOR rungata NOT FOUND IN THE WEATHER API
# Retrieving weather data for union, city ID:5105640
# Retrieving weather data for sinnamary, city ID:3380290
# Retrieving weather data for skibotn, city ID:7626405
# Retrieving weather data for dayong, city ID:1789289
# Retrieving weather data for aksarka, city ID:1512019
# Retrieving weather data for dingle, city ID:1714733
# Retrieving weather data for homagama, city ID:1243936
# Retrieving weather data for marzuq, city ID:72181
# Retrieving weather data for griffith, city ID:4920986
# Retrieving weather data for djambala, city ID:2260401
# DATA FOR dolbeau NOT FOUND IN THE WEATHER API
# Retrieving weather data for pyaozerskiy, city ID:503581
# Retrieving weather data for bathsheba, city ID:3374083
# Retrieving weather data for novoagansk, city ID:1497210
# Retrieving weather data for rumoi, city ID:2128382
# Retrieving weather data for jalu, city ID:86049
# Retrieving weather data for inuvik, city ID:5983607
# Retrieving weather data for tiznit, city ID:2527087
# Retrieving weather data for port blair, city ID:1259385
# Retrieving weather data for soledade, city ID:3447423
# Retrieving weather data for akyab, city ID:1295765
# Retrieving weather data for outjo, city ID:3353715
# Retrieving weather data for arrifes, city ID:3373329
# Retrieving weather data for dauriya, city ID:2025099
# Retrieving weather data for port hardy, city ID:6111862
# Retrieving weather data for taitung, city ID:6949678
# Retrieving weather data for bonfim, city ID:3405215
# Retrieving weather data for yuzhno-kurilsk, city ID:2119447
# Retrieving weather data for killybegs, city ID:2963295
# Retrieving weather data for howick, city ID:995202
# Retrieving weather data for victoria, city ID:1819729
# Retrieving weather data for bilibino, city ID:2126682
# Retrieving weather data for ouango, city ID:236844
# Retrieving weather data for caravelas, city ID:3466980
# Retrieving weather data for creston, city ID:4853078
# Retrieving weather data for sorong, city ID:1626542
# Retrieving weather data for doka, city ID:376332
# Retrieving weather data for arya, city ID:1184330
# Retrieving weather data for komatipoort, city ID:988290
# Retrieving weather data for tokur, city ID:2015217
# Retrieving weather data for ulladulla, city ID:2145554
# Retrieving weather data for panguipulli, city ID:3877348
# Retrieving weather data for miri, city ID:1738050
# Retrieving weather data for mukhen, city ID:2019718
# Retrieving weather data for vershino-darasunskiy, city ID:2013442
# Retrieving weather data for necochea, city ID:3430443
# Retrieving weather data for karpathos, city ID:260895
# DATA FOR kamenskoye NOT FOUND IN THE WEATHER API
# Retrieving weather data for agadez, city ID:2448083
# DATA FOR hunza NOT FOUND IN THE WEATHER API
# Retrieving weather data for tigil, city ID:2120612
# Retrieving weather data for jinchang, city ID:1805733
# DATA FOR alotau NOT FOUND IN THE WEATHER API
# Retrieving weather data for saint-augustin, city ID:6137462
# Retrieving weather data for kafue, city ID:915883
# Retrieving weather data for naliya, city ID:1262062
# Retrieving weather data for belen, city ID:321572
# Retrieving weather data for veisiejai, city ID:593338
# Retrieving weather data for kot addu, city ID:1173378
# Retrieving weather data for mayya, city ID:2020121
# Retrieving weather data for nome, city ID:5870133
# Retrieving weather data for chuzhou, city ID:1814757
# Retrieving weather data for usinsk, city ID:863061
# Retrieving weather data for beringovskiy, city ID:2126710
# DATA FOR umzimvubu NOT FOUND IN THE WEATHER API
# Retrieving weather data for sault sainte marie, city ID:6141439
# Retrieving weather data for nyurba, city ID:2018735
# Retrieving weather data for penzance, city ID:2640377
# Retrieving weather data for saint anthony, city ID:5044290
# Retrieving weather data for katangli, city ID:2122783
# Retrieving weather data for hirara, city ID:1862505
# Retrieving weather data for abaete, city ID:3473267
# Retrieving weather data for shimoda, city ID:1852357
# Retrieving weather data for inongo, city ID:2315417
# Retrieving weather data for kathmandu, city ID:1283240
# Retrieving weather data for dunkwa, city ID:2301400
# Retrieving weather data for derzhavinsk, city ID:1524606
# Retrieving weather data for kugulta, city ID:539781
# Retrieving weather data for ixtapa, city ID:4004293
# Retrieving weather data for gabu, city ID:2372532
# Retrieving weather data for saldanha, city ID:3361934
# Retrieving weather data for gizo, city ID:2108857
# Retrieving weather data for chegutu, city ID:894239
# Retrieving weather data for republic, city ID:4405434
# Retrieving weather data for tura, city ID:1254046
# Retrieving weather data for hit, city ID:95788
# Retrieving weather data for cheney, city ID:5789856
# Retrieving weather data for dukat, city ID:2125906
# Retrieving weather data for skibbereen, city ID:2961459
# Retrieving weather data for grand gaube, city ID:934479
# DATA FOR tarudant NOT FOUND IN THE WEATHER API
# Retrieving weather data for kudahuvadhoo, city ID:1337607
# Retrieving weather data for maraa, city ID:3663475
# DATA FOR teneguiban NOT FOUND IN THE WEATHER API

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create a dictionary of the list for combination into a single dataframe.
cities_dict ={
    "City": city_name,
    "Latitude": city_lats,
    "Longtitude": city_lngs,
    "Max Temperature": max_temp,
    "Humidity" : humidity,
    "Cloudiness" : cloudiness,
    "Wind Speed" : wind_speed,
    "Time of Data": city_datetime,
    "Country Code" : city_country
}
# Create the initial dataframe from the above dictionary.
cities_df = pd.DataFrame(cities_dict)
cities_df.head(100)
# Out:
#                  City  Latitude  Longtitude  Max Temperature  Humidity  \
# 0               Kapaa     22.08     -159.32            80.60        78
# 1               Pisco    -13.70      -76.22            62.60        77
# 2              Narsaq     60.92      -46.05            48.20        76
# 3              Samaná     19.21      -69.34            79.63        89
# 4            Sulangan     11.14      123.72            83.17        73
# ..                ...       ...         ...              ...       ...
# 95               Suhl     50.60       10.70            57.99        80
# 96            Labuhan     -6.88      112.21            79.30        67
# 97    Havre-St-Pierre     50.23      -63.60            60.80        87
# 98        Panama City      8.99      -79.52            79.00        94
# 99  Saint Paul Harbor     57.79     -152.41            69.80        49
#
#     Cloudiness  Wind Speed  Time of Data Country Code
# 0           90       14.99    1595986556           US
# 1           90        5.82    1595986454           PE
# 2          100        3.36    1595986557           GL
# 3          100        9.13    1595986557           DO
# 4           98        7.85    1595986557           PH
# ..         ...         ...           ...          ...
# 95          17        2.04    1595986579           DE
# 96         100        8.86    1595986580           ID
# 97          90        8.05    1595986580           CA
# 98          96        5.82    1595986575           PA
# 99           1        4.70    1595986293           US
#
# [100 rows x 9 columns]

# %%
cities_df.to_csv("../Resources/cities_weather_data.csv", encoding="utf-8", index=False)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# first, let's check if there are any cities with a humidity grater than 100
cities_df['Humidity'].max()
# Out:
# 100

# %%
#  Get the indices of cities that have humidity over 100%. if there are then filter them out.
if cities_df['Humidity'].max() > 100:
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
    clean_city_data = cities_df[cities_df['Humidity'] <= 100]
else:
    clean_city_data = cities_df

clean_city_data.shape
# Out:
# (579, 9)

# %%
# Extract relevant fields from the data frame


# Export the City_Data into a csv

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
analysis_date = today.strftime("%B %d, %Y")
plt.scatter(clean_city_data['Latitude'],clean_city_data['Max Temperature'])

plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title(f"Latitude vs. Temperature\n Analysis date: {analysis_date}\n")
plt.grid(True)

# Save the plot to the png folder
plt.savefig("../png/latitude_vs_temp.png")

# Show the plot
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
analysis_date = today.strftime("%B %d, %Y")
plt.scatter(clean_city_data['Latitude'],clean_city_data['Humidity'])

plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title(f"Latitude vs. Humidity \n Analysis date: {analysis_date}\n")
plt.grid(True)

# Save the plot to the png folder
plt.savefig("../png/latitude_vs_humidity.png")

# Show the plot
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
analysis_date = today.strftime("%B %d, %Y")
plt.scatter(clean_city_data['Latitude'],clean_city_data['Cloudiness'])

plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title(f"Latitude vs. Cloudiness (%) \n Analysis date: {analysis_date}\n")
plt.grid(True)

# Save the plot to the png folder
plt.savefig("../png/latitude_vs_cloudiness.png")

# Show the plot
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
analysis_date = today.strftime("%B %d, %Y")
plt.scatter(clean_city_data['Latitude'],clean_city_data['Wind Speed'])

plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title(f"Latitude vs. Wind Speed \n Analysis date: {analysis_date}\n")
plt.grid(True)

# Save the plot to the png folder
plt.savefig("../png/latitude_vs_wind_speed.png")

# Show the plot
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
